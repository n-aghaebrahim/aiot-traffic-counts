# %%
import argparse
from math import sqrt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
# Mount Google Drive if necessary
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/AAI530/Final Project/traffic-volume-counts-1.csv')

# %%
df['SegmentID'].value_counts()
# Out:
# 76510     70
# 107111    70
# 77328     70
# 77424     70
# 91529     70
#           ..
# 1885       2
# 41760      2
# 41759      2
# 1886       2
# 202        1
# Name: SegmentID, Length: 1956, dtype: int64

# %%
# 76510 has the most rows
# We can use this as the dataset for the daily traffic count

# Get all the rows that have 76510
df_new = df.loc[df['SegmentID']==76510]

print('Unique directions of SegmentID 76510')
print(df_new['Direction'].value_counts())

col_names = df_new.columns
# Out:
# Unique directions of SegmentID 76510
# EB    35
# WB    35
# Name: Direction, dtype: int64

# %%
# Separate data into EB and WB
data_EB = []
data_WB = []
# Find average traffic volume per day
for i in range(len(df_new)):
  traffic_data = []
  for j in range(7, df_new.shape[1]):
    traffic_data.append(df_new[col_names[j]].iloc[i])
  traffic_data_mean = np.mean(traffic_data)
  if df_new['Direction'].iloc[i] == 'EB':
    data_EB.append(traffic_data_mean)
  else:
    data_WB.append(traffic_data_mean)

# %%
print(len(data_EB))
print(len(data_WB))
# Out:
# 35
# 35

# %%
df_new.head()
# Out:
#         ID  SegmentID Roadway Name       From         To Direction  \
# 1931  1929      76510    31 AVENUE  87 STREET  88 STREET        EB
# 1932  1930      76510    31 AVENUE  87 STREET  88 STREET        EB
# 1933  1931      76510    31 AVENUE  87 STREET  88 STREET        EB
# 1934  1932      76510    31 AVENUE  87 STREET  88 STREET        EB
# 1935  1933      76510    31 AVENUE  87 STREET  88 STREET        EB
#
#             Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  ...  2:00-3:00PM  \
# 1931  01/25/2012           56.0         32.0         26.0  ...        200.0
# 1932  01/26/2012           55.0         29.0         21.0  ...        211.0
# 1933  01/27/2012           45.0         31.0         20.0  ...        206.0
# 1934  01/28/2012          101.0         53.0         52.0  ...        212.0
# 1935  01/29/2012          118.0         96.0         84.0  ...        173.0
#
#       3:00-4:00PM  4:00-5:00PM  5:00-6:00PM  6:00-7:00PM  7:00-8:00PM  \
# 1931        275.0        241.0        304.0        236.0        185.0
# 1932        247.0        235.0        281.0        262.0        190.0
# 1933        277.0        258.0        294.0        290.0        193.0
# 1934        214.0        235.0        251.0        222.0        175.0
# 1935        201.0        184.0        163.0        195.0        177.0
#
#       8:00-9:00PM  9:00-10:00PM  10:00-11:00PM  11:00-12:00AM
# 1931        129.0         105.0           94.0           66.0
# 1932        127.0         124.0           83.0           55.0
# 1933        169.0         136.0          113.0           85.0
# 1934        165.0         151.0          136.0          125.0
# 1935        144.0         117.0           95.0           67.0
#
# [5 rows x 31 columns]

# %%
# Create list of sequences for training
seq_length = 10
pred_horiz = 2

seq_arrays = []
seq_labs = []

# only for EB so far
for i in range(0,len(data_EB)-seq_length-pred_horiz):
  seq_arrays.append(data_EB[i:i+seq_length])
  seq_labs.append(data_EB[i+seq_length+pred_horiz-1])  # subtract 1 for zero-indexing

# convert to numpy arrays and floats for keras/tensorflow
seq_arrays = np.array(seq_arrays, dtype=object).astype(np.float32)
seq_labs = np.array(seq_labs, dtype=object).astype(np.float32)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from contextlib import redirect_stdout

# model = Sequential([
#         layers.LSTM(50, activation='relu', input_shape=(seq_length, 1)),
#         layers.Dense(100, activation='relu'),
#         layers.Dense(1)
#     ])
# model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error')
# print(model.summary())
# with open(results_dir+'/lstm_model_summary.txt', 'w') as f:
#   with redirect_stdout(f):
#     model.summary()

# %%
# history = model.fit(seq_arrays, seq_labs, epochs=100, batch_size=500, validation_split=0.05, verbose=2)

# print(history.history.keys())

# %%
def create_conv_lstm_model(n_steps, n_features, filter_num=64, kernel_size=3, pool_size=2, lstm_units=50, dense_units=100, dropout_rate=0.2, learning_rate=0.001, results_dir="./results"):
  """
  Creates and compiles a Convolutional LSTM model for sequence data processing, integrating
  Conv1D and LSTM layers with Dropout for regularization.

  Parameters:
  - n_steps: Integer, number of time steps in each input sample.
  - n_features: Integer, number of features in each input sample.
  - filter_num: Integer, number of filters in the Conv1D layer (default 64).
  - kernel_size: Integer, size of the convolution kernel (default 3).
  - pool_size: Integer, size of the pooling window (default 2).
  - lstm_units: Integer, number of units in the LSTM layer (default 50).
  - dense_units: Integer, number of units in the Dense layer (default 100).
  - dropout_rate: Float between 0 and 1, fraction of the input units to drop (default 0.2).
  - learning_rate: Float, learning rate for the Adam optimizer (default 0.001).

  Returns:
  - Compiled Keras model ready for training.
  """
  model = Sequential([
      layers.Input(shape=(n_steps, n_features)),
      layers.Conv1D(filters=filter_num, kernel_size=kernel_size, activation='relu'),
      layers.MaxPooling1D(pool_size=pool_size),
      layers.Flatten(),
      layers.Reshape((1, -1)),  # Reshape for LSTM layer
      layers.LSTM(units=lstm_units, activation='relu'),
      layers.Dropout(dropout_rate),
      layers.Dense(units=dense_units, activation='relu'),
      layers.Dropout(dropout_rate),
      layers.Dense(1)  # Output layer
  ])

  model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mean_squared_error', metrics=['mean_absolute_error'])

  #with open(results_dir+'/conv_lstm_model_summary.txt', 'w') as f:
      #with redirect_stdout(f):
  print(model.summary())

  return model

model_conv = create_conv_lstm_model(n_steps=seq_length, n_features=1)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 8, 64)             256
#
#  max_pooling1d_2 (MaxPoolin  (None, 4, 64)             0
#  g1D)
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  reshape_2 (Reshape)         (None, 1, 256)            0
#
#  lstm_3 (LSTM)               (None, 50)                61400
#
#  dropout_4 (Dropout)         (None, 50)                0
#
#  dense_6 (Dense)             (None, 100)               5100
#
#  dropout_5 (Dropout)         (None, 100)               0
#
#  dense_7 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 66857 (261.16 KB)
# Trainable params: 66857 (261.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
history = model_conv.fit(seq_arrays, seq_labs, epochs=100, batch_size=500, validation_split=0.05, verbose=2)

print(history.history.keys())
# Out:
# Epoch 1/100
# 1/1 - 3s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 3s/epoch - 3s/step
# Epoch 2/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 58ms/epoch - 58ms/step
# Epoch 3/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 66ms/epoch - 66ms/step
# Epoch 4/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 61ms/epoch - 61ms/step
# Epoch 5/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 60ms/epoch - 60ms/step
# Epoch 6/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 69ms/epoch - 69ms/step
# Epoch 7/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 49ms/epoch - 49ms/step
# Epoch 8/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 63ms/epoch - 63ms/step
# Epoch 9/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 63ms/epoch - 63ms/step
# Epoch 10/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 50ms/epoch - 50ms/step
# Epoch 11/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 67ms/epoch - 67ms/step
# Epoch 12/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 51ms/epoch - 51ms/step
# Epoch 13/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 70ms/epoch - 70ms/step
# Epoch 14/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 57ms/epoch - 57ms/step
# Epoch 15/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 51ms/epoch - 51ms/step
# Epoch 16/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 65ms/epoch - 65ms/step
# Epoch 17/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 66ms/epoch - 66ms/step
# Epoch 18/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 81ms/epoch - 81ms/step
# Epoch 19/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 34ms/epoch - 34ms/step
# Epoch 20/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 33ms/epoch - 33ms/step
# Epoch 21/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 37ms/epoch - 37ms/step
# Epoch 22/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 33ms/epoch - 33ms/step
# Epoch 23/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 34ms/epoch - 34ms/step
# Epoch 24/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 33ms/epoch - 33ms/step
# Epoch 25/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 34ms/epoch - 34ms/step
# Epoch 26/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 40ms/epoch - 40ms/step
# Epoch 27/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 35ms/epoch - 35ms/step
# Epoch 28/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 36ms/epoch - 36ms/step
# Epoch 29/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 33ms/epoch - 33ms/step
# Epoch 30/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 33ms/epoch - 33ms/step
# Epoch 31/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 37ms/epoch - 37ms/step
# Epoch 32/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 36ms/epoch - 36ms/step
# Epoch 33/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 34ms/epoch - 34ms/step
# Epoch 34/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 34ms/epoch - 34ms/step
# Epoch 35/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 33ms/epoch - 33ms/step
# Epoch 36/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 35ms/epoch - 35ms/step
# Epoch 37/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 38ms/epoch - 38ms/step
# Epoch 38/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 34ms/epoch - 34ms/step
# Epoch 39/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 35ms/epoch - 35ms/step
# Epoch 40/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 35ms/epoch - 35ms/step
# Epoch 41/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 36ms/epoch - 36ms/step
# Epoch 42/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 32ms/epoch - 32ms/step
# Epoch 43/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 35ms/epoch - 35ms/step
# Epoch 44/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 54ms/epoch - 54ms/step
# Epoch 45/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 39ms/epoch - 39ms/step
# Epoch 46/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 33ms/epoch - 33ms/step
# Epoch 47/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 34ms/epoch - 34ms/step
# Epoch 48/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 35ms/epoch - 35ms/step
# Epoch 49/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 35ms/epoch - 35ms/step
# Epoch 50/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 35ms/epoch - 35ms/step
# Epoch 51/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 34ms/epoch - 34ms/step
# Epoch 52/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 52ms/epoch - 52ms/step
# Epoch 53/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 43ms/epoch - 43ms/step
# Epoch 54/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 52ms/epoch - 52ms/step
# Epoch 55/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 36ms/epoch - 36ms/step
# Epoch 56/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 51ms/epoch - 51ms/step
# Epoch 57/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 36ms/epoch - 36ms/step
# Epoch 58/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 33ms/epoch - 33ms/step
# Epoch 59/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 35ms/epoch - 35ms/step
# Epoch 60/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 34ms/epoch - 34ms/step
# Epoch 61/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 32ms/epoch - 32ms/step
# Epoch 62/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 35ms/epoch - 35ms/step
# Epoch 63/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 34ms/epoch - 34ms/step
# Epoch 64/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 36ms/epoch - 36ms/step
# Epoch 65/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 33ms/epoch - 33ms/step
# Epoch 66/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 37ms/epoch - 37ms/step
# Epoch 67/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 38ms/epoch - 38ms/step
# Epoch 68/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 51ms/epoch - 51ms/step
# Epoch 69/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 51ms/epoch - 51ms/step
# Epoch 70/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 36ms/epoch - 36ms/step
# Epoch 71/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 35ms/epoch - 35ms/step
# Epoch 72/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 36ms/epoch - 36ms/step
# Epoch 73/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 34ms/epoch - 34ms/step
# Epoch 74/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 41ms/epoch - 41ms/step
# Epoch 75/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 34ms/epoch - 34ms/step
# Epoch 76/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 35ms/epoch - 35ms/step
# Epoch 77/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 35ms/epoch - 35ms/step
# Epoch 78/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 37ms/epoch - 37ms/step
# Epoch 79/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 33ms/epoch - 33ms/step
# Epoch 80/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 33ms/epoch - 33ms/step
# Epoch 81/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 33ms/epoch - 33ms/step
# Epoch 82/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 32ms/epoch - 32ms/step
# Epoch 83/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 35ms/epoch - 35ms/step
# Epoch 84/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 32ms/epoch - 32ms/step
# Epoch 85/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 34ms/epoch - 34ms/step
# Epoch 86/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 31ms/epoch - 31ms/step
# Epoch 87/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 31ms/epoch - 31ms/step
# Epoch 88/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 36ms/epoch - 36ms/step
# Epoch 89/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 51ms/epoch - 51ms/step
# Epoch 90/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 32ms/epoch - 32ms/step
# Epoch 91/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 31ms/epoch - 31ms/step
# Epoch 92/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 36ms/epoch - 36ms/step
# Epoch 93/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 33ms/epoch - 33ms/step
# Epoch 94/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 43ms/epoch - 43ms/step
# Epoch 95/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 32ms/epoch - 32ms/step
# Epoch 96/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 39ms/epoch - 39ms/step
# Epoch 97/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 33ms/epoch - 33ms/step
# Epoch 98/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 35ms/epoch - 35ms/step
# Epoch 99/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 33ms/epoch - 33ms/step
# Epoch 100/100
# 1/1 - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 36ms/epoch - 36ms/step
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])
